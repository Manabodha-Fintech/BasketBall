# %%
import os
import json
import requests
from dotenv import load_dotenv

# %%
# Load API key from .env file
load_dotenv()
API_KEY = os.getenv("SPORTSRADAR_API_KEY")

if not API_KEY:
    raise ValueError("❌ API Key not found in .env file")

# %%
# Read game IDs from series_game_ids.json
year = '2024'
file_path = f'../../data/ncaamb/api_data/game_ids/{year}_season_ids.json'
with open(file_path, "r") as f:
    series_games = json.load(f)

# %%
def fetch_game_details(game_id, api_key):
    url = f"https://api.sportradar.com/ncaamb/trial/v8/en/games/{game_id}/summary.json"
    headers = {
        "accept": "application/json",
        "x-api-key": api_key
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
os.makedirs(f'../../data/ncaamb/api_data/match_stats/{year}',exist_ok=True)

# %%
all_game_ids = [gid for games in series_games.values() for gid in games]
total_ids = len(all_game_ids)
print(f"📊 Total games to fetch: {total_ids}")
success, fail = 0, 0

for idx, game_id in enumerate(all_game_ids, start=1):
        try:
            data = fetch_game_details(game_id, API_KEY)

            # Save file as games/<game_id>.json
            file_path = os.path.join(f"../../data/ncaamb/api_data/match_stats/{year}/{game_id}.json")
            with open(file_path, "w") as f:
                json.dump(data, f, indent=4)

            success += 1
            print(f"✅ {idx}/{total_ids} Saved {game_id}.json (Success: {success}, Fail: {fail})")

        except Exception as e:
            fail += 1
            print(f"❌ {idx}/{total_ids} Failed {game_id}: {e} (Success: {success}, Fail: {fail})")

print(f"\n🎯 Finished! {success} succeeded, {fail} failed out of {total_ids}")
# Out:
# 📊 Total games to fetch: 105
# ✅ 1/105 Saved 2816af39-63e9-4cf2-93e2-3fd370bd4a25.json (Success: 1, Fail: 0)
# ✅ 2/105 Saved c8abb602-7854-4aab-b15b-ab2c8bf6838b.json (Success: 2, Fail: 0)
# ✅ 3/105 Saved 764171e9-1ccf-4861-b472-282d1e421b39.json (Success: 3, Fail: 0)
# ✅ 4/105 Saved f38c754f-a528-466f-8438-41e08123cb72.json (Success: 4, Fail: 0)
# ✅ 5/105 Saved 092a3e36-990f-41bc-bc8f-4315add01017.json (Success: 5, Fail: 0)
# ✅ 6/105 Saved fbeb127c-9504-43ec-9874-4e8b1600eb01.json (Success: 6, Fail: 0)
# ✅ 7/105 Saved 3ce0e22e-f05e-46b3-ae2f-1ceb6a49ccc7.json (Success: 7, Fail: 0)
# ✅ 8/105 Saved 7d3c0c96-6be4-436e-affb-35a343035dc1.json (Success: 8, Fail: 0)
# ✅ 9/105 Saved 33a40cf2-4769-4edb-9df4-a14986e5ec18.json (Success: 9, Fail: 0)
# ✅ 10/105 Saved c228ef43-e90b-4341-97bd-054b85df49ec.json (Success: 10, Fail: 0)
# ✅ 11/105 Saved bdc401ff-e6d6-4623-a1f4-408705a915f3.json (Success: 11, Fail: 0)
# ✅ 12/105 Saved d60841a9-6b9b-41da-bd82-1e59629542c3.json (Success: 12, Fail: 0)
# ✅ 13/105 Saved 9912a6ef-0c5d-492f-a647-b9816850994e.json (Success: 13, Fail: 0)
# ✅ 14/105 Saved 6d658b2a-46ce-4d68-9549-5a58e4cbd5d6.json (Success: 14, Fail: 0)
# ✅ 15/105 Saved 313cdec3-401c-4ec5-a1f9-149497344ec4.json (Success: 15, Fail: 0)
# ✅ 16/105 Saved 1ea4f2c4-b14f-4fcb-b41a-a89124e5b587.json (Success: 16, Fail: 0)
# ✅ 17/105 Saved d616b321-a3ea-441c-96c2-a82ee85cf636.json (Success: 17, Fail: 0)
# ✅ 18/105 Saved 3da1a8d8-336d-4339-8b21-9f25ea304f00.json (Success: 18, Fail: 0)
# ✅ 19/105 Saved 40f200ea-2354-4c6d-b85c-4c859082bf38.json (Success: 19, Fail: 0)
# ✅ 20/105 Saved 8f3a83e1-e7c9-4a7e-8554-2694de5a564e.json (Success: 20, Fail: 0)
# ✅ 21/105 Saved 423e0a4a-0658-4d10-83fd-e5648a50f274.json (Success: 21, Fail: 0)
# ✅ 22/105 Saved b651c772-7bc0-46d6-aabe-2de2a086b294.json (Success: 22, Fail: 0)
# ✅ 23/105 Saved 6addb107-85ea-4ce6-8a3a-180f23f646bc.json (Success: 23, Fail: 0)
# ✅ 24/105 Saved 6331b877-377a-47df-bf53-a73fab3eadfc.json (Success: 24, Fail: 0)
# ✅ 25/105 Saved 285eda51-e375-4efa-8239-7c10c17ff5c5.json (Success: 25, Fail: 0)
# ✅ 26/105 Saved 40a00886-feb1-4f6b-99a7-eb21851b2e9e.json (Success: 26, Fail: 0)
# ✅ 27/105 Saved b334809a-1dd5-4615-9d48-81e687e75db7.json (Success: 27, Fail: 0)
# ✅ 28/105 Saved eaec1797-0096-4ae0-87fb-f85b341a7cd9.json (Success: 28, Fail: 0)
# ✅ 29/105 Saved 5385a0b3-87aa-46ea-9294-16cffeff4c50.json (Success: 29, Fail: 0)
# ✅ 30/105 Saved 98ecc4a2-3c2a-48ee-8cad-8897945710c4.json (Success: 30, Fail: 0)
# ✅ 31/105 Saved 96924293-8510-4c1e-a014-0f49871b4a3f.json (Success: 31, Fail: 0)
# ✅ 32/105 Saved fbad5e1b-cff1-4a52-abb6-15de4e3529d0.json (Success: 32, Fail: 0)
# ✅ 33/105 Saved 98a455f1-f6b1-4299-85a9-f1488b0d0cd2.json (Success: 33, Fail: 0)
# ✅ 34/105 Saved 1e8a1165-fcad-4a08-92c3-2a51f7cd62c2.json (Success: 34, Fail: 0)
# ✅ 35/105 Saved 84848181-930d-4dff-b8bf-5c137eeb3388.json (Success: 35, Fail: 0)
# ✅ 36/105 Saved 4d043420-21a4-42a5-a8c8-80fc31a72376.json (Success: 36, Fail: 0)
# ✅ 37/105 Saved e4f4b43c-8242-4f8c-9db9-a676601eba2b.json (Success: 37, Fail: 0)
# ✅ 38/105 Saved 8a293e6e-c828-4b1a-b66f-c0c41932c192.json (Success: 38, Fail: 0)
# ✅ 39/105 Saved ed1da9c0-d741-4937-b5d3-8187d790094e.json (Success: 39, Fail: 0)
# ✅ 40/105 Saved 25bd18cd-bc49-4568-b1d7-e5aaeb995e7e.json (Success: 40, Fail: 0)
# ✅ 41/105 Saved 67d4fd1b-6832-4ee8-ae67-2a53b5d879cb.json (Success: 41, Fail: 0)
# ✅ 42/105 Saved 0851c137-1d87-4d4a-b09e-6443afa2fa06.json (Success: 42, Fail: 0)
# ✅ 43/105 Saved a63744b9-947b-4a48-ae24-1faf939fa5f1.json (Success: 43, Fail: 0)
# ✅ 44/105 Saved 1f88e4bc-3062-4215-ad5f-af114125abce.json (Success: 44, Fail: 0)
# ✅ 45/105 Saved 271b361c-07a8-496d-a846-8de6f766580a.json (Success: 45, Fail: 0)
# ✅ 46/105 Saved 0d5d5c0a-5e43-4dba-a6a2-26b9d08e0f6b.json (Success: 46, Fail: 0)
# ✅ 47/105 Saved 8b0d344b-83d4-4189-bec0-b6962b3a9b40.json (Success: 47, Fail: 0)
# ✅ 48/105 Saved a3717687-f541-46d9-96ca-8230288237ef.json (Success: 48, Fail: 0)
# ✅ 49/105 Saved f71cb64f-4d52-4e2b-a3db-7436b798476d.json (Success: 49, Fail: 0)
# ✅ 50/105 Saved 2288617a-4a44-440a-ae72-88928d36c637.json (Success: 50, Fail: 0)
# ✅ 51/105 Saved 47ed63a4-16b1-40d2-af78-4b01cec36024.json (Success: 51, Fail: 0)
# ✅ 52/105 Saved 85a3bd42-d89d-441b-bf1b-88f8e8eca60c.json (Success: 52, Fail: 0)
# ✅ 53/105 Saved 8522459e-1c09-4848-b087-af3c9d1bfc65.json (Success: 53, Fail: 0)
# ✅ 54/105 Saved 5c7cd68d-6980-4adc-b877-debb7bf09ae9.json (Success: 54, Fail: 0)
# ✅ 55/105 Saved 31e10527-4fdf-4ccc-8769-0325ba706ff3.json (Success: 55, Fail: 0)
# ✅ 56/105 Saved 46d06a7e-139b-4d86-89e5-f797a12ecf5e.json (Success: 56, Fail: 0)
# ✅ 57/105 Saved 22b5922f-6fcc-41e5-a958-52966ebe77b7.json (Success: 57, Fail: 0)
# ✅ 58/105 Saved dc991c88-8a5e-4820-8664-593270e4eea7.json (Success: 58, Fail: 0)
# ✅ 59/105 Saved 33bcba73-8e85-40c8-a619-ecf31a307372.json (Success: 59, Fail: 0)
# ✅ 60/105 Saved c815cbf1-a269-42df-94a1-31e28197ca9e.json (Success: 60, Fail: 0)
# ✅ 61/105 Saved f9784a1c-0fa2-4054-b76f-847f211f99cb.json (Success: 61, Fail: 0)
# ✅ 62/105 Saved 109c9c7b-90c7-4b78-8909-c082f3e15fb7.json (Success: 62, Fail: 0)
# ✅ 63/105 Saved e5414812-fe89-431b-aa32-31b9643d8ed7.json (Success: 63, Fail: 0)
# ✅ 64/105 Saved 0df9c38c-61c4-446b-bb19-c3d4125c882e.json (Success: 64, Fail: 0)
# ✅ 65/105 Saved 06654eb6-4c77-4f3f-a4ec-645a84bb5fe5.json (Success: 65, Fail: 0)
# ✅ 66/105 Saved 871424b6-0330-4483-b3b8-4ae74f0e67cb.json (Success: 66, Fail: 0)
# ✅ 67/105 Saved 12431918-0d94-422d-9cd5-bc92396c3fc3.json (Success: 67, Fail: 0)
# ✅ 68/105 Saved ea2ff21f-2f43-4242-af27-803cc2f9b14a.json (Success: 68, Fail: 0)
# ✅ 69/105 Saved 6c437aa2-fd9a-4656-912f-a85a4c9d2677.json (Success: 69, Fail: 0)
# ✅ 70/105 Saved 046d813a-a80b-4c27-8078-b7fc06076a5d.json (Success: 70, Fail: 0)
# ✅ 71/105 Saved 36497a74-1b93-4891-9312-3c30c60986f5.json (Success: 71, Fail: 0)
# ✅ 72/105 Saved f2190d51-8287-4438-a458-d0bce6701e39.json (Success: 72, Fail: 0)
# ✅ 73/105 Saved a1f02443-0774-4d86-acd3-87b30df45fd0.json (Success: 73, Fail: 0)
# ✅ 74/105 Saved 4dcfec1b-f67a-49f5-a3eb-cba43244d7a4.json (Success: 74, Fail: 0)
# ✅ 75/105 Saved 0f6f9fda-9049-4bfb-9c8e-1b5739de7497.json (Success: 75, Fail: 0)
# ✅ 76/105 Saved 64f3c2d8-5c4c-4e16-8b0b-2a78815b8dc7.json (Success: 76, Fail: 0)
# ✅ 77/105 Saved b3c171d3-fe65-4623-80ef-d772764519ce.json (Success: 77, Fail: 0)
# ✅ 78/105 Saved 1ef93701-3124-4907-bec8-9ffffb822827.json (Success: 78, Fail: 0)
# ✅ 79/105 Saved 3515fd91-5d23-4a2b-9ab4-5b36b18be3f8.json (Success: 79, Fail: 0)
# ✅ 80/105 Saved f7026a37-1b71-4fc5-90f3-d9f6d3f25fe2.json (Success: 80, Fail: 0)
# ✅ 81/105 Saved 894325e6-3e6d-420e-a6f7-c525f50385ec.json (Success: 81, Fail: 0)
# ✅ 82/105 Saved 8061c051-2537-4c5e-8e98-b03dabcfb4db.json (Success: 82, Fail: 0)
# ✅ 83/105 Saved 2c6c63a0-a94b-40b4-8910-79ebc1dcd7bb.json (Success: 83, Fail: 0)
# ✅ 84/105 Saved 8d2846bb-2495-4c52-a851-64b872cb8437.json (Success: 84, Fail: 0)
# ✅ 85/105 Saved 07d0fb78-4a96-470d-ba3a-c59f5b86fdd6.json (Success: 85, Fail: 0)
# ✅ 86/105 Saved da963689-db3e-424c-8465-75c9bffc9266.json (Success: 86, Fail: 0)
# ✅ 87/105 Saved d018cf8b-fc84-4201-a719-ae4ee9b47d54.json (Success: 87, Fail: 0)
# ✅ 88/105 Saved 95cda9da-009d-4869-a9ab-e5462ad1292a.json (Success: 88, Fail: 0)
# ✅ 89/105 Saved cbf67496-d405-4a87-876c-9dde69772bfa.json (Success: 89, Fail: 0)
# ✅ 90/105 Saved b08315a7-4ae0-4661-a408-c2a2da3f0c80.json (Success: 90, Fail: 0)
# ✅ 91/105 Saved 8b307e2a-c8f2-4ca6-8557-1381f16412b5.json (Success: 91, Fail: 0)
# ✅ 92/105 Saved 7d73f71b-70dd-4a9b-9333-cd595456a42f.json (Success: 92, Fail: 0)
# ✅ 93/105 Saved 6341b1a0-82c2-48df-916b-f9ae746b718b.json (Success: 93, Fail: 0)
# ✅ 94/105 Saved a91f289f-3bfb-46cc-8a32-03008bd5436a.json (Success: 94, Fail: 0)
# ✅ 95/105 Saved 455cabbc-0d72-4b39-bcf9-7f06030ff43b.json (Success: 95, Fail: 0)
# ✅ 96/105 Saved 8fa94e28-df93-4000-9913-109128e31d66.json (Success: 96, Fail: 0)
# ✅ 97/105 Saved 9dc4eed7-2176-4f64-86b9-8f3e470549c5.json (Success: 97, Fail: 0)
# ✅ 98/105 Saved 335637a5-e6c5-4243-8ac3-9dd2dc7ee185.json (Success: 98, Fail: 0)
# ✅ 99/105 Saved 971b7fb5-de69-417c-8104-fb915f71eccd.json (Success: 99, Fail: 0)
# ✅ 100/105 Saved bc17e6c6-d6ae-40c5-bc79-7be576f35ec7.json (Success: 100, Fail: 0)
# ✅ 101/105 Saved ac098af2-4a2d-4b7d-a0d5-cb5b8c164d62.json (Success: 101, Fail: 0)
# ✅ 102/105 Saved 90d1195d-6ccd-4c4f-a855-6d50ec564b79.json (Success: 102, Fail: 0)
# ✅ 103/105 Saved 51282c87-8a92-45b1-932f-078c8385a049.json (Success: 103, Fail: 0)
# ✅ 104/105 Saved 80f29d3a-e1a0-4ddd-8349-8f652180f42e.json (Success: 104, Fail: 0)
# ✅ 105/105 Saved b0034b8f-1c53-4d53-bfb5-464947ec9b40.json (Success: 105, Fail: 0)
#
# 🎯 Finished! 105 succeeded, 0 failed out of 105
