# %%
import os
import json
import requests
from dotenv import load_dotenv

# %%
# Load API key from .env file
load_dotenv()
API_KEY = os.getenv("SPORTSRADAR_API_KEY")

if not API_KEY:
    raise ValueError("❌ API Key not found in .env file")

# %%
# Read game IDs from series_game_ids.json
year = '2024'
season_type = 'PST'
file_path = f'../../data/ncaamb/api_data/game_ids/{year}_{season_type}_season_ids.json'
with open(file_path, "r") as f:
    series_games = json.load(f)

# %%
def fetch_game_details(game_id, api_key):
    url = f"https://api.sportradar.com/ncaamb/trial/v8/en/games/{game_id}/summary.json"
    headers = {
        "accept": "application/json",
        "x-api-key": api_key
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
os.makedirs(f'../../data/ncaamb/api_data/match_stats/{year}',exist_ok=True)

# %%
all_game_ids = series_games
total_ids = len(all_game_ids)
print(f"📊 Total games to fetch: {total_ids}")
failed_game_ids = []
success, fail = 0, 0

for idx, game_id in enumerate(all_game_ids, start=1):
        # if idx < 265:
        #      continue
        try:
            data = fetch_game_details(game_id, API_KEY)

            # Save file as games/<game_id>.json
            file_path = os.path.join(f"../../data/ncaamb/api_data/match_stats/{year}/{season_type}_{game_id}.json")
            with open(file_path, "w") as f:
                json.dump(data, f, indent=4)

            success += 1
            print(f"✅ {idx}/{total_ids} Saved {game_id}.json (Success: {success}, Fail: {fail})")

        except Exception as e:
            fail += 1
            failed_game_ids.append(game_id)
            print(f"❌ {idx}/{total_ids} Failed {game_id}: {e} (Success: {success}, Fail: {fail})")

print(f"\n🎯 Finished! {success} succeeded, {fail} failed out of {total_ids}")
# Out:
# 📊 Total games to fetch: 123
# ✅ 1/123 Saved 6b6f93e6-82a5-49cb-a876-8924a8fefb02.json (Success: 1, Fail: 0)
# ✅ 2/123 Saved 87aba6fd-5818-4581-b5f3-6b3933f09735.json (Success: 2, Fail: 0)
# ✅ 3/123 Saved d0b75834-f061-4ad5-b5da-738f44756b74.json (Success: 3, Fail: 0)
# ✅ 4/123 Saved b186e603-b1fd-4fd4-95ab-3372ca23a470.json (Success: 4, Fail: 0)
# ✅ 5/123 Saved 805b09d3-242e-467e-bae2-f8e574d2d6b5.json (Success: 5, Fail: 0)
# ✅ 6/123 Saved 85247677-88e5-4dfa-bf81-948490572f41.json (Success: 6, Fail: 0)
# ✅ 7/123 Saved 20550a1c-27c9-4e8d-8010-886fc66b3749.json (Success: 7, Fail: 0)
# ✅ 8/123 Saved 7eaf8c43-01f7-4907-bab7-892ab7f106dc.json (Success: 8, Fail: 0)
# ✅ 9/123 Saved 9d9c8870-7fd7-49ba-b7cd-20eafe75152f.json (Success: 9, Fail: 0)
# ✅ 10/123 Saved 441d025e-44bb-4c22-9c9a-3b1edf260852.json (Success: 10, Fail: 0)
# ✅ 11/123 Saved 4263114d-a7d9-45ed-830e-f6403a4d33f7.json (Success: 11, Fail: 0)
# ✅ 12/123 Saved 4d7b22b6-a2e6-4dee-9d6d-d60642ebc23c.json (Success: 12, Fail: 0)
# ✅ 13/123 Saved caddfd95-5d4e-420c-be2a-651f607c29ca.json (Success: 13, Fail: 0)
# ✅ 14/123 Saved 55a65c8f-54a1-4f87-8707-e97729cfe41d.json (Success: 14, Fail: 0)
# ✅ 15/123 Saved a2105eb3-f220-47f2-bc70-6d67776c3089.json (Success: 15, Fail: 0)
# ✅ 16/123 Saved 3c68478f-7826-40f7-8e80-d1ae46169298.json (Success: 16, Fail: 0)
# ✅ 17/123 Saved 345b34fd-c31f-405e-906b-c08099833d23.json (Success: 17, Fail: 0)
# ✅ 18/123 Saved 8b9c0168-66be-4e4e-897e-2cf5cd7801c4.json (Success: 18, Fail: 0)
# ✅ 19/123 Saved 221b6c81-431f-4516-9321-4af657f84099.json (Success: 19, Fail: 0)
# ✅ 20/123 Saved debe1db6-1631-4cae-a08f-6b5ae7ccfa37.json (Success: 20, Fail: 0)
# ✅ 21/123 Saved 95285257-0761-4571-8dcd-040fbf230b91.json (Success: 21, Fail: 0)
# ✅ 22/123 Saved 36813a2c-031e-4528-bdf6-2b5e312b46c1.json (Success: 22, Fail: 0)
# ✅ 23/123 Saved a4cd6141-222b-4cd0-b32f-cbe15f5fbb9c.json (Success: 23, Fail: 0)
# ✅ 24/123 Saved 94f6607f-f2db-492b-acb9-07146f8781f2.json (Success: 24, Fail: 0)
# ✅ 25/123 Saved b3098a73-f322-4987-bed2-a08de6030088.json (Success: 25, Fail: 0)
# ✅ 26/123 Saved 813259f9-d01a-42bd-b957-bf8ef2c377e8.json (Success: 26, Fail: 0)
# ✅ 27/123 Saved 11773774-6849-4b68-8aac-e04695eef2ce.json (Success: 27, Fail: 0)
# ✅ 28/123 Saved dac703ed-a894-4604-bb3d-d2b40a552240.json (Success: 28, Fail: 0)
# ✅ 29/123 Saved 12b2259d-4ac9-44c1-b01d-ddaedf436936.json (Success: 29, Fail: 0)
# ✅ 30/123 Saved c089908c-aa41-4f47-a6e4-dfb174556ddc.json (Success: 30, Fail: 0)
# ✅ 31/123 Saved c066781a-6092-4b96-844b-a67da2674f5b.json (Success: 31, Fail: 0)
# ✅ 32/123 Saved 2171663b-5340-4da8-9b73-fc23bd664cc2.json (Success: 32, Fail: 0)
# ✅ 33/123 Saved dde15af8-3a88-43ff-b00d-3f30359a5c36.json (Success: 33, Fail: 0)
# ✅ 34/123 Saved 15c8d98b-f66d-4d51-a784-dfc9bdeac4c4.json (Success: 34, Fail: 0)
# ✅ 35/123 Saved 2e73d50b-38d3-4fcd-b907-a695699259bd.json (Success: 35, Fail: 0)
# ✅ 36/123 Saved b8e00402-17e0-4720-bec3-307e49249089.json (Success: 36, Fail: 0)
# ✅ 37/123 Saved eeae8b31-8665-4b57-9c8d-028b09374e7e.json (Success: 37, Fail: 0)
# ✅ 38/123 Saved 733b1fba-e396-4e14-910a-1e201ff95a48.json (Success: 38, Fail: 0)
# ✅ 39/123 Saved e8bf579b-62f5-4fc8-9b27-5ef0ef4a8e4f.json (Success: 39, Fail: 0)
# ✅ 40/123 Saved e858f388-bb1c-4f58-8fb3-8faf93f61a35.json (Success: 40, Fail: 0)
# ✅ 41/123 Saved 3a98d5a7-4b11-4342-b12a-9b623fab534e.json (Success: 41, Fail: 0)
# ✅ 42/123 Saved 8ecec46a-9c15-4bf6-9596-dc4002ad46ba.json (Success: 42, Fail: 0)
# ✅ 43/123 Saved 4793460a-c60c-4d89-811d-e3759c049156.json (Success: 43, Fail: 0)
# ✅ 44/123 Saved 2c7ff907-8502-48c3-8e10-7be83df6f7c9.json (Success: 44, Fail: 0)
# ✅ 45/123 Saved df32ec4b-7dd0-4f4b-85cf-3d2d31a87a92.json (Success: 45, Fail: 0)
# ✅ 46/123 Saved 5d02bb8c-61ac-41bf-b286-e4846e09deea.json (Success: 46, Fail: 0)
# ✅ 47/123 Saved c6f49159-89f8-4094-b153-e0cce89ca31e.json (Success: 47, Fail: 0)
# ✅ 48/123 Saved 252055f7-a334-4310-aa6c-d05de0453a96.json (Success: 48, Fail: 0)
# ✅ 49/123 Saved a6672cc7-8ed6-4785-a792-eafe31ca6b66.json (Success: 49, Fail: 0)
# ✅ 50/123 Saved 7ed6589d-3acd-453b-be65-a937f02849be.json (Success: 50, Fail: 0)
# ✅ 51/123 Saved fb03dac5-6aad-4377-a717-1afd67381710.json (Success: 51, Fail: 0)
# ✅ 52/123 Saved e948dc39-61cb-4476-8e9c-b541cf02b94c.json (Success: 52, Fail: 0)
# ✅ 53/123 Saved e203f0ed-7b6c-4fcc-9947-c78ac7263575.json (Success: 53, Fail: 0)
# ✅ 54/123 Saved 295af7e1-2aa7-405a-b01d-35692b4cd795.json (Success: 54, Fail: 0)
# ✅ 55/123 Saved 1cf9ac01-fbae-4439-a7b0-2aa85e053ffb.json (Success: 55, Fail: 0)
# ✅ 56/123 Saved 873d7ea3-dc91-400e-a870-1352b6ef5951.json (Success: 56, Fail: 0)
# ✅ 57/123 Saved 7ca005fe-7318-4804-878f-b84157194938.json (Success: 57, Fail: 0)
# ✅ 58/123 Saved 3415bff0-e724-4fea-8a52-cd2686715bf7.json (Success: 58, Fail: 0)
# ✅ 59/123 Saved f6fa2902-60ce-48d3-8e49-8f8818b44c99.json (Success: 59, Fail: 0)
# ✅ 60/123 Saved 73e940b8-6ca7-4d6c-b872-6d9c86d554e2.json (Success: 60, Fail: 0)
# ✅ 61/123 Saved 7d60bf86-e533-48f3-a1bf-eb7834ce1737.json (Success: 61, Fail: 0)
# ✅ 62/123 Saved dc69d64d-30d8-4819-80ee-32382f22e2c5.json (Success: 62, Fail: 0)
# ✅ 63/123 Saved 4c0d44d5-bb76-42c3-ac86-31f121229b2c.json (Success: 63, Fail: 0)
# ✅ 64/123 Saved a7d13773-7f83-42b8-9c25-4309afe0bdda.json (Success: 64, Fail: 0)
# ✅ 65/123 Saved 0955bcb3-dbf8-4d83-a043-10694e09e17c.json (Success: 65, Fail: 0)
# ✅ 66/123 Saved 52842780-b1be-4b61-85ab-024b0b255535.json (Success: 66, Fail: 0)
# ✅ 67/123 Saved 124c6d1a-e15a-452e-9c46-2c1af9003138.json (Success: 67, Fail: 0)
# ✅ 68/123 Saved fd5902ee-bd50-400a-93af-5e99ff91e39e.json (Success: 68, Fail: 0)
# ✅ 69/123 Saved 4ae6a446-9abe-42a4-801c-c74112ec98b2.json (Success: 69, Fail: 0)
# ✅ 70/123 Saved 3dd00f23-7dfe-49b5-b2bf-36b2cbaccf88.json (Success: 70, Fail: 0)
# ✅ 71/123 Saved 02f18667-fce6-450a-93ac-d764218c8893.json (Success: 71, Fail: 0)
# ✅ 72/123 Saved 3e2fb2b7-5eae-427f-aa29-01a0eacd54c5.json (Success: 72, Fail: 0)
# ✅ 73/123 Saved 9824003c-6a13-41a5-a595-4550dd97eb33.json (Success: 73, Fail: 0)
# ✅ 74/123 Saved 6ddcbada-61b8-41d0-8e07-0cd1d4b5944f.json (Success: 74, Fail: 0)
# ✅ 75/123 Saved 847fede1-e5a1-4a93-8500-f5e56a7d939b.json (Success: 75, Fail: 0)
# ✅ 76/123 Saved 934f2861-e3de-48bb-8fbc-1166d73453f3.json (Success: 76, Fail: 0)
# ✅ 77/123 Saved 513066b5-cbee-4609-8cc7-3f9226ea3683.json (Success: 77, Fail: 0)
# ✅ 78/123 Saved 78686985-731e-4dcd-bca5-35deeb5278b9.json (Success: 78, Fail: 0)
# ✅ 79/123 Saved d1583a95-e7de-48a6-8862-a8eeb6071834.json (Success: 79, Fail: 0)
# ✅ 80/123 Saved bd8680fd-83e0-41cf-89ab-fd593b56aad0.json (Success: 80, Fail: 0)
# ✅ 81/123 Saved 71faf531-c33b-4586-8706-a84aa94a4175.json (Success: 81, Fail: 0)
# ✅ 82/123 Saved 11a50677-08f9-44a1-810e-6db5aa3f8f9e.json (Success: 82, Fail: 0)
# ✅ 83/123 Saved 83e2cb76-033b-47ac-abfd-8d44070bcf34.json (Success: 83, Fail: 0)
# ✅ 84/123 Saved 8eb4449f-3954-4726-b9e7-693c77c8d9a8.json (Success: 84, Fail: 0)
# ✅ 85/123 Saved b0308027-6bb4-48e1-b352-d05dd61e32f3.json (Success: 85, Fail: 0)
# ✅ 86/123 Saved 54044caf-db9e-4b8b-ac74-e5c0f036bcc1.json (Success: 86, Fail: 0)
# ✅ 87/123 Saved 5ee07172-65bc-45ae-9170-76e6c52ccb00.json (Success: 87, Fail: 0)
# ✅ 88/123 Saved 231d99bc-0f99-417d-b100-c3f26e2fa08b.json (Success: 88, Fail: 0)
# ✅ 89/123 Saved c6ee5843-f2e2-4d95-9cf3-bd7db8e3f21a.json (Success: 89, Fail: 0)
# ✅ 90/123 Saved 3cc7adaa-9677-4b3f-aa98-c614a6227bad.json (Success: 90, Fail: 0)
# ✅ 91/123 Saved 1e401f9f-578b-41bd-8023-b455cdf1127c.json (Success: 91, Fail: 0)
# ✅ 92/123 Saved ebd32876-a662-4c46-9a45-4a80d4ece16a.json (Success: 92, Fail: 0)
# ✅ 93/123 Saved 03d89af8-b1d2-4902-af28-78f4755cf474.json (Success: 93, Fail: 0)
# ✅ 94/123 Saved 6e9314b1-daa4-40b2-b660-c20fec61be4c.json (Success: 94, Fail: 0)
# ✅ 95/123 Saved eedb6cfb-c577-49bf-a37e-37f6db2d59c1.json (Success: 95, Fail: 0)
# ✅ 96/123 Saved 8b09beb1-d9eb-4144-8eb2-4c2f6de60c55.json (Success: 96, Fail: 0)
# ✅ 97/123 Saved 410638db-2d32-471f-a082-47fd27879c07.json (Success: 97, Fail: 0)
# ✅ 98/123 Saved d1bf7dfc-49bb-4f4f-9edf-fec338033e79.json (Success: 98, Fail: 0)
# ✅ 99/123 Saved 090bae5a-117b-40af-b2b0-347c1a8f1789.json (Success: 99, Fail: 0)
# ✅ 100/123 Saved 646d85fd-9c06-469a-b874-1ecf835c456c.json (Success: 100, Fail: 0)
# ✅ 101/123 Saved e9329b26-7854-4ffc-ae12-19a075a63b31.json (Success: 101, Fail: 0)
# ✅ 102/123 Saved be07b127-a053-44a4-846a-a940e7688cd6.json (Success: 102, Fail: 0)
# ✅ 103/123 Saved c834e2da-1755-46da-938c-a8f50e7e7adb.json (Success: 103, Fail: 0)
# ✅ 104/123 Saved ebfe6412-85ad-4cd0-95d0-44a15c4cd7be.json (Success: 104, Fail: 0)
# ✅ 105/123 Saved b2aa6405-434e-4682-a768-1f497303261b.json (Success: 105, Fail: 0)
# ✅ 106/123 Saved 28b61789-9fcb-4a46-a52d-59836a741f67.json (Success: 106, Fail: 0)
# ✅ 107/123 Saved 04c53efa-2823-4b83-83c2-596dcfc8b685.json (Success: 107, Fail: 0)
# ✅ 108/123 Saved 230018cd-1b80-4a55-a727-4d383d6cabbb.json (Success: 108, Fail: 0)
# ✅ 109/123 Saved 506f141a-126f-456b-b2e0-f757c1c1ee29.json (Success: 109, Fail: 0)
# ✅ 110/123 Saved 04fbdd6c-47b3-422e-b118-9e235b224f16.json (Success: 110, Fail: 0)
# ✅ 111/123 Saved 421d1053-c097-4512-9ac2-dfae90d7fab1.json (Success: 111, Fail: 0)
# ✅ 112/123 Saved 4e66358c-20bb-4a0d-a3a7-3435abc7f731.json (Success: 112, Fail: 0)
# ✅ 113/123 Saved 610d1a52-13c2-4023-9ca7-7d36133dbac5.json (Success: 113, Fail: 0)
# ✅ 114/123 Saved 58b2c96d-6794-4b59-80e9-e7462f13b56d.json (Success: 114, Fail: 0)
# ✅ 115/123 Saved 8e3c59e0-a8d2-4d3f-90cd-b6010ecaeb28.json (Success: 115, Fail: 0)
# ✅ 116/123 Saved ebcea9a7-64df-46fd-8b21-b37e8555848f.json (Success: 116, Fail: 0)
# ✅ 117/123 Saved 9a330b59-1712-4c60-9838-9282f6902dfd.json (Success: 117, Fail: 0)
# ✅ 118/123 Saved fa15684d-0966-46e7-a3f8-f1d378692109.json (Success: 118, Fail: 0)
# ✅ 119/123 Saved fdf2494c-7ca2-4e9a-ad73-3f1dba3aa67b.json (Success: 119, Fail: 0)
# ✅ 120/123 Saved eaba35d4-535f-45b9-b38e-a614a9907e2c.json (Success: 120, Fail: 0)
# ✅ 121/123 Saved 827d2ffd-3d6b-42e6-b089-62b7b8e664d0.json (Success: 121, Fail: 0)
# ✅ 122/123 Saved 296f6ab2-c9bf-4387-93d1-64e6d375595c.json (Success: 122, Fail: 0)
# ✅ 123/123 Saved cd3a3fd5-48de-428a-8444-0d27a6993805.json (Success: 123, Fail: 0)
#
# 🎯 Finished! 123 succeeded, 0 failed out of 123

# %%
failed_game_ids_file_path = f'../../data/ncaamb/api_data/failed_game_ids/{year}_{season_type}_season_ids.json'
with open(failed_game_ids_file_path, "w") as f:
    json.dump(failed_game_ids, f, indent=4)
